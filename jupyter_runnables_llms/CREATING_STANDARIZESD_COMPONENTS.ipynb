# %%
from abc import ABC , abstractclassmethod

# %%
class Runnable(ABC):
    @abstractmethod
    def invoke(input_data):
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 class Runnable(ABC):
#       2     @abstractmethod
#       3     def invoke(input_data):
#       4         pass
#
# Cell In[29], line 2, in Runnable()
#       1 class Runnable(ABC):
# ----> 2     @abstractmethod
#       3     def invoke(input_data):
#       4         pass
#
# NameError: name 'abstractmethod' is not defined

# %%
import random
class NakaliLLM(Runnable):

    def __init__(self):
        print('LLM Created')

    def invoke(self, prompt):
        
         response_list =[

            'Delhi is the capital of INDIA',
            'IPL is a cricket legue',
            'AI stands for Artificial Inteligence'
        ]

    def predict(self, prompt):

        response_list =[

            'Delhi is the capital of INDIA',
            'IPL is a cricket legue',
            'AI stands for Artificial Inteligence'
        ]

        return {'response' : random.choice(response_list)}

# %%
class NakliPromptTemplate(Runnable):
    
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def invoke(self, input_dict):
        return self.template.format(**input_dict)

    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
class NakliStrOutputParser(Runnable):
    def __init__(self):
        pass

    def invoke(self, input_data)
# Out:
#   Cell In[32], line 5
#     def invoke(self, input_data)
#                                            ^
# SyntaxError: expected ':'

# %%
# now we connect and build the chain togather

# %%
class RunnableConnector(Runnable):
    def __init__(self, runnable_list):
        self.runnable_list = runnable_list

    def invoke(self, input_data):

        for runnable in runnable_list:
            input_data = ruunable.invoke(input_data)

        return input_data

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables = [ 'length','topic']
)

# %%
llm = NakaliLLM()
# Out:
# LLM Created

# %%
parser = NakliStrOutputParser()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 parser = NakliStrOutputParser()
#
# NameError: name 'NakliStrOutputParser' is not defined

# %%
chain = RunnableConnector([template , llm, parser])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 chain = RunnableConnector([template , llm, parser])
#
# NameError: name 'parser' is not defined

# %%
chain.invoke({'length':'long' , 'topic' :'india'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 chain.invoke({'length':'long' , 'topic' :'india'})
#
# NameError: name 'chain' is not defined
